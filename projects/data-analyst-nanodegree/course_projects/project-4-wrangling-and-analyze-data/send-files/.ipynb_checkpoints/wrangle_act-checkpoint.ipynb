# %% [markdown]
# # Data Wrangling Project - WeRateDogs Twitter

# %% [markdown]
# ## Introduction
# Real-world data rarely comes clean. Using Python and its libraries, you will gather data from a variety of sources and in a variety of formats, assess its quality and tidiness, then clean it. This is called data wrangling. You will document your wrangling efforts in a Jupyter Notebook, plus showcase them through analyses and visualizations using Python (and its libraries) and/or SQL.
#
# The dataset that you will be wrangling (and analyzing and visualizing) is the tweet archive of Twitter user @dog_rates, also known as WeRateDogs. WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. These ratings almost always have a denominator of 10. The numerators, though? Almost always greater than 10. 11/10, 12/10, 13/10, etc. Why? Because "they're good dogs Brent." WeRateDogs has over 4 million followers and has received international media coverage.
#
# WeRateDogs downloaded their Twitter archive and sent it to Udacity via email exclusively for you to use in this project. This archive contains basic tweet data (tweet ID, timestamp, text, etc.) for all 5000+ of their tweets as they stood on August 1, 2017. More on this soon.
#
# WeRateDogs banner
# Image via Boston Magazine
#
# What Software Do I Need?
# The entirety of this project can be completed inside the Udacity classroom on the Project Workspace: Complete and Submit Project page using the Jupyter Notebook provided there. (Note: This Project Workspace may not be available in all versions of this project, in which case you should follow the directions below.)
#
# If you want to work outside of the Udacity classroom, the following software requirements apply:
#
# - You need to be able to work in a Jupyter Notebook on your computer. Please revisit our Jupyter Notebook and Anaconda tutorials earlier in the Nanodegree program for installation instructions.
# - The following packages (libraries) need to be installed. You can install these packages via conda or pip. Please revisit our Anaconda tutorial earlier in the Nanodegree program for package installation instructions.
#     - pandas
#     - NumPy
#     - requests
#     - tweepy
#     - json
# - You need to be able to create written documents that contain images and you need to be able to export these documents as PDF files. This task can be done in a Jupyter Notebook, but you might prefer to use a word processor like Google Docs, which is free, or Microsoft Word.
# - A text editor, like Sublime, which is free, will be useful but is not required.
#
# ## Context
# Your goal: wrangle WeRateDogs Twitter data to create interesting and trustworthy analyses and visualizations. The Twitter archive is great, but it only contains very basic tweet information. Additional gathering, then assessing and cleaning is required for "Wow!"-worthy analyses and visualizations.
#
# ## The Data
# **Enhanced Twitter Archive**
#
# The WeRateDogs Twitter archive contains basic tweet data for all 5000+ of their tweets, but not everything. One column the archive does contain though: each tweet's text, which I used to extract rating, dog name, and dog "stage" (i.e. doggo, floofer, pupper, and puppo) to make this Twitter archive "enhanced." Of the 5000+ tweets, I have filtered for tweets with ratings only (there are 2356).
#
# image 1
#
# I extracted this data programmatically, but I didn't do a very good job. The ratings probably aren't all correct. Same goes for the dog names and probably dog stages (see below for more information on these) too. You'll need to assess and clean these columns if you want to use them for analysis and visualization.
#
# image 2
#
# **Additional Data via the Twitter API**
#
# Back to the basic-ness of Twitter archives: retweet count and favorite count are two of the notable column omissions. Fortunately, this additional data can be gathered by anyone from Twitter's API. Well, "anyone" who has access to data for the 3000 most recent tweets, at least. But you, because you have the WeRateDogs Twitter archive and specifically the tweet IDs within it, can gather this data for all 5000+. And guess what? You're going to query Twitter's API to gather this valuable data.
#
# **Image Predictions File**
#
# One more cool thing: I ran every image in the WeRateDogs Twitter archive through a neural network that can classify breeds of dogs*. The results: a table full of image predictions (the top three only) alongside each tweet ID, image URL, and the image number that corresponded to the most confident prediction (numbered 1 to 4 since tweets can have up to four images).
#
# image 3
#
# So for the last row in that table:
#
# - tweet_id is the last part of the tweet URL after "status/" → https://twitter.com/dog_rates/status/889531135344209921
# - p1 is the algorithm's #1 prediction for the image in the tweet → golden retriever
# - p1_conf is how confident the algorithm is in its #1 prediction → 95%
# - p1_dog is whether or not the #1 prediction is a breed of dog → TRUE
# - p2 is the algorithm's second most likely prediction → Labrador retriever
# - p2_conf is how confident the algorithm is in its #2 prediction → 1%
# - p2_dog is whether or not the #2 prediction is a breed of dog → TRUE
# - etc.
#
# And the #1 prediction for the image in that tweet was spot on:
#
# image 4
#
# So that's all fun and good. But all of this additional data will need to be gathered, assessed, and cleaned. This is where you come in.
#
# Key Points
# Key points to keep in mind when data wrangling for this project:
#
# - You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# - Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# - Cleaning includes merging individual pieces of data according to the rules of tidy data.
# - The fact that the rating numerators are greater than the denominators does not need to be cleaned. This unique rating system is a big part of the popularity of WeRateDogs.
# - You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.
#
# *Fun fact: creating this neural network is one of the projects in Udacity's Data Scientist Nanodegree, Machine Learning Engineer Nanodegree and Artificial Intelligence Nanodegree programs.
#
# ## Project Details
# Your tasks in this project are as follows:
#
# - Data wrangling, which consists of:
#     - Gathering data (downloadable file in the Resources tab in the left most panel of your classroom and linked in step 1 below).
#     - Assessing data
#     - Cleaning data
#     - Storing, analyzing, and visualizing your wrangled data
#     - Reporting on 1) your data wrangling efforts and 2) your data analyses and visualizations
#
# **Gathering Data for this Project**
#
# Gather each of the three pieces of data as described below in a Jupyter Notebook titled wrangle_act.ipynb:
#
# - The WeRateDogs Twitter archive. I am giving this file to you, so imagine it as a file on hand. Download this file manually by clicking the following link: twitter_archive_enhanced.csv
#
# - The tweet image predictions, i.e., what breed of dog (or other object, animal, etc.) is present in each tweet according to a neural network. This file (image_predictions.tsv) is hosted on Udacity's servers and should be downloaded programmatically using the Requests library and the following URL: https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv
#
# - Each tweet's retweet count and favorite ("like") count at minimum, and any additional data you find interesting. Using the tweet IDs in the WeRateDogs Twitter archive, query the Twitter API for each tweet's JSON data using Python's Tweepy library and store each tweet's entire set of JSON data in a file called tweet_json.txt file. Each tweet's JSON data should be written to its own line. Then read this .txt file line by line into a pandas DataFrame with (at minimum) tweet ID, retweet count, and favorite count. Note: do not include your Twitter API keys, secrets, and tokens in your project submission.
#
# If you decide to complete your project in the Project Workspace, note that you can upload files to the Jupyter Notebook Workspace by clicking the "Upload" button in the top righthand corner of the dashboard.
#
# **Assessing Data for this Project**
#
# After gathering each of the above pieces of data, assess them visually and programmatically for quality and tidiness issues. Detect and document at least eight (8) quality issues and two (2) tidiness issues in your wrangle_act.ipynb Jupyter Notebook. To meet specifications, the issues that satisfy the Project Motivation (see the Key Points header on the previous page) must be assessed.
#
# **Cleaning Data for this Project**
#
# Clean each of the issues you documented while assessing. Perform this cleaning in wrangle_act.ipynb as well. The result should be a high quality and tidy master pandas DataFrame (or DataFrames, if appropriate). Again, the issues that satisfy the Project Motivation must be cleaned.
#
# **Storing, Analyzing, and Visualizing Data for this Project**
#
# Store the clean DataFrame(s) in a CSV file with the main one named twitter_archive_master.csv. If additional files exist because multiple tables are required for tidiness, name these files appropriately. Additionally, you may store the cleaned data in a SQLite database (which is to be submitted as well if you do).
#
# Analyze and visualize your wrangled data in your wrangle_act.ipynb Jupyter Notebook. At least three (3) insights and one (1) visualization must be produced.
#
# **Reporting for this Project**
#
# Create a 300-600 word written report called wrangle_report.pdf or wrangle_report.html that briefly describes your wrangling efforts. This is to be framed as an internal document.
#
# Create a 250-word-minimum written report called act_report.pdf or act_report.html that communicates the insights and displays the visualization(s) produced from your wrangled data. This is to be framed as an external document, like a blog post or magazine article, for example.
#
# Both of these documents can be created in separate Jupyter Notebooks using the Markdown functionality of Jupyter Notebooks, then downloading those notebooks as PDF files or HTML files (see image below). You might prefer to use a word processor like Google Docs or Microsoft Word, however.
#
# image 5

# %% [markdown]
# ## Gathering data

# %%
#import libs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import os

# %% [markdown]
# ### WeRateDogs Twitter archive
# This file was downloaded manually by clicking on the link provided by Udacity.

# %%
#Load file
df_twitter_enhanced = pd.read_csv('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/data/twitter-archive-enhanced-2.csv')
df_twitter_enhanced.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
#Check count
df_twitter_enhanced.count()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           78
# in_reply_to_user_id             78
# timestamp                     2356
# source                        2356
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id       181
# retweeted_status_timestamp     181
# expanded_urls                 2297
# rating_numerator              2356
# rating_denominator            2356
# name                          2356
# doggo                         2356
# floofer                       2356
# pupper                        2356
# puppo                         2356
# dtype: int64

# %% [markdown]
# ### Tweet image predictions
# This file (image_predictions.tsv) is hosted on Udacity's servers and should be downloaded programmatically using the Requests library

# %%
#Download file using requests
folder_name = 'c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/data'
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
with open(os.path.join(folder_name,
                      url.split('/')[-1]),mode = 'wb') as file:
    file.write(response.content)

# %%
df_twitter_img_pred = pd.read_csv('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/data/image-predictions.tsv',sep='\t')
df_twitter_img_pred.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
#Check count
df_twitter_img_pred.count()
# Out:
# tweet_id    2075
# jpg_url     2075
# img_num     2075
# p1          2075
# p1_conf     2075
# p1_dog      2075
# p2          2075
# p2_conf     2075
# p2_dog      2075
# p3          2075
# p3_conf     2075
# p3_dog      2075
# dtype: int64

# %% [markdown]
# ### Twitter api
# Additional data would need to be gather through the twitter api, but as I couldn't get this access I decided to follow the alternative way provided by Udacity. This altertative is:
# - Copy and paste api code in notebook to documentate
# - Read the text file provided by Udacity

# %%
#Api code, to documentate
"""
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)
"""
# Out:
# '\nimport tweepy\nfrom tweepy import OAuthHandler\nimport json\nfrom timeit import default_timer as timer\n\n# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file\n# These are hidden to comply with Twitter\'s API terms and conditions\nconsumer_key = \'HIDDEN\'\nconsumer_secret = \'HIDDEN\'\naccess_token = \'HIDDEN\'\naccess_secret = \'HIDDEN\'\n\nauth = OAuthHandler(consumer_key, consumer_secret)\nauth.set_access_token(access_token, access_secret)\n\napi = tweepy.API(auth, wait_on_rate_limit=True)\n\n# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:\n# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to\n# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv\n# NOTE TO REVIEWER: this student had mobile verification issues so the following\n# Twitter API code was sent to this student from a Udacity instructor\n# Tweet IDs for which to gather additional data via Twitter\'s API\ntweet_ids = df_
# ...

# %%
#Read the txt file
df_twitter_additional = pd.read_json('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/data/tweet-json.txt',lines=True)
df_twitter_additional.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           33819
# ...

# %%
#Check columns
df_twitter_additional.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')

# %%
#Choose only columns that will be used
df_twitter_additional = df_twitter_additional[['id','favorite_count','retweet_count','lang']]
df_twitter_additional.head()
# Out:
#                    id  favorite_count  retweet_count lang
# 0  892420643555336193           39467           8853   en
# 1  892177421306343426           33819           6514   en
# 2  891815181378084864           25461           4328   en
# 3  891689557279858688           42908           8964   en
# 4  891327558926688256           41048           9774   en

# %% [markdown]
# ## Assessing data

# %% [markdown]
# ### WeRateDogs Twitter archive

# %%
#Visualize the data
df_twitter_enhanced
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
#Checking the text, source, rating_numerator and rating_denominator
with pd.option_context('display.max_colwidth', -1):
  display(df_twitter_enhanced[['text','source','rating_numerator','rating_denominator']])
# Out:
#                                                                                                                                                                         text  \
# 0     This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU
# 1     This is Tilly. She's just checking pup on you. Hopes you're doing ok. If not, she's available for pats, snugs, boops, the whole bit. 13/10 https://t.co/0Xxu71qeIV
# 2     This is Archie. He is a rare Norwegian Pouncing Corgo. Lives in the tall grass. You never know when one may strike. 12/10 https://t.co/wUnZnhtVJB
# 3     This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
# 4     This is Franklin. He would like you to stop calling him "cute." He is a very fierce shark and should be respected as such. 12/10 #BarkWeek https://t.co/AtUZn91f7f
# ...

# %%
#Check dog stages columns
df_twitter_enhanced.groupby(['doggo','floofer','pupper','puppo']).count()['tweet_id'].reset_index()
# Out:
#    doggo  floofer  pupper  puppo  tweet_id
# 0   None     None    None   None      1976
# 1   None     None    None  puppo        29
# 2   None     None  pupper   None       245
# 3   None  floofer    None   None         9
# 4  doggo     None    None   None        83
# 5  doggo     None    None  puppo         1
# 6  doggo     None  pupper   None        12
# 7  doggo  floofer    None   None         1

# %%
#Analyze dogs with 2 stages
with pd.option_context('display.max_colwidth', -1):
  display(df_twitter_enhanced[(df_twitter_enhanced['doggo'] =='doggo') & (df_twitter_enhanced['pupper'] =='pupper')][['text']])
# Out:
#                                                                                                                                                                       text
# 460   This is Dido. She's playing the lead role in "Pupper Stops to Catch Snow Before Resuming Shadow Box with Dried Apple." 13/10 (IG: didodoggo) https://t.co/m7isZrOBX7
# 531   Here we have Burke (pupper) and Dexter (doggo). Pupper wants to be exactly like doggo. Both 12/10 would pet at same time https://t.co/ANBpEYHaho
# 565   Like doggo, like pupper version 2. Both 11/10 https://t.co/9IxWAXFqze
# 575   This is Bones. He's being haunted by another doggo of roughly the same size. 12/10 deep breaths pupper everything's fine https://t.co/55Dqe0SJNj
# 705   This is Pinot. He's a sophisticated doggo. You can tell by the hat. Also pointier than your average pupper. Still 10/10 would pet cautiously https://t.co/f2wmLZTPHd
# 733   Pupper butt 1, Doggo 0. Both 12/10 https://t.co/WQvcPEpH2u
# ...

# %% [markdown]
# According to the texts, it is possible for the dog to have 2 stages

# %%
df_twitter_enhanced.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
#Check info
df_twitter_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
#Check describe
df_twitter_enhanced.describe()
# Out:
#            tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# count  2.356000e+03           7.800000e+01         7.800000e+01
# mean   7.427716e+17           7.455079e+17         2.014171e+16
# std    6.856705e+16           7.582492e+16         1.252797e+17
# min    6.660209e+17           6.658147e+17         1.185634e+07
# 25%    6.783989e+17           6.757419e+17         3.086374e+08
# 50%    7.196279e+17           7.038708e+17         4.196984e+09
# 75%    7.993373e+17           8.257804e+17         4.196984e+09
# max    8.924206e+17           8.862664e+17         8.405479e+17
#
#        retweeted_status_id  retweeted_status_user_id  rating_numerator  \
# count         1.810000e+02              1.810000e+02       2356.000000
# mean          7.720400e+17              1.241698e+16         13.126486
# std           6.236928e+16              9.599254e+16         45.876648
# min           6.661041e+17              7.832140e+05          0.000000
# ...

# %%
#Check retweets
df_twitter_enhanced.retweeted_status_id.notnull().sum()
# Out:
# 181

# %%
#Check in reply
df_twitter_enhanced.in_reply_to_status_id.notnull().sum()
# Out:
# 78

# %% [markdown]
# **Quality issues**
# - Columns names that do not express the data well
# - The dog stages columns is not accurate
# - There are no columns for dog stages snoot and blep (Missing data)
# - Rating denominator less or greather then 10
# - The source column is with html tag text
# - The timestamp column as an object instead of a date
# - We have retweets and in replies
#
# **Tidiness issues**
# - All dog stage columns can become a single column

# %% [markdown]
# ### Tweet image predictions

# %%
#Visualize the data
df_twitter_img_pred
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %%
#Check info
df_twitter_img_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 119.6+ KB

# %%
#Set option to suppress scientific notation
pd.set_option('display.float_format', lambda x: '%.6f' % x)
#Check describe
df_twitter_img_pred.describe()
# Out:
#                        tweet_id     img_num     p1_conf     p2_conf  \
# count               2075.000000 2075.000000 2075.000000 2075.000000
# mean  738451357852539008.000000    1.203855    0.594548    0.134589
# std    67852033330235656.000000    0.561875    0.271174    0.100666
# min   666020888022790144.000000    1.000000    0.044333    0.000000
# 25%   676483507139540992.000000    1.000000    0.364412    0.053886
# 50%   711998809858043904.000000    1.000000    0.588230    0.118181
# 75%   793203448525178880.000000    1.000000    0.843855    0.195566
# max   892420643555336192.000000    4.000000    1.000000    0.488014
#
#           p3_conf
# count 2075.000000
# mean     0.060324
# std      0.050906
# min      0.000000
# 25%      0.016222
# 50%      0.049444
# 75%      0.091808
# max      0.273419

# %%
df_twitter_img_pred.groupby(['p1_dog','p2_dog','p3_dog']).count()['tweet_id'].reset_index()
# Out:
#    p1_dog  p2_dog  p3_dog  tweet_id
# 0   False   False   False       324
# 1   False   False    True        64
# 2   False    True   False        54
# 3   False    True    True       101
# 4    True   False   False        43
# 5    True   False    True        91
# 6    True    True   False       155
# 7    True    True    True      1243

# %%
#Check p1 breed
df_twitter_img_pred[df_twitter_img_pred['p1_dog'] == True]['p1'].value_counts()
# Out:
# golden_retriever               150
# Labrador_retriever             100
# Pembroke                        89
# Chihuahua                       83
# pug                             57
# chow                            44
# Samoyed                         43
# toy_poodle                      39
# Pomeranian                      38
# malamute                        30
# cocker_spaniel                  30
# French_bulldog                  26
# miniature_pinscher              23
# Chesapeake_Bay_retriever        23
# Siberian_husky                  20
# Staffordshire_bullterrier       20
# German_shepherd                 20
# Cardigan                        19
# Maltese_dog                     18
# beagle                          18
# Eskimo_dog                      18
# Shetland_sheepdog               18
# Shih-Tzu                        17
# Lakeland_terrier                17
# Rottweiler                      17
# Italian_greyhound               16
# kuvasz                          16
# ...

# %%
#Check p2 breed
df_twitter_img_pred[df_twitter_img_pred['p2_dog'] == True]['p2'].value_counts()
# Out:
# Labrador_retriever                104
# golden_retriever                   92
# Cardigan                           73
# Chihuahua                          44
# Pomeranian                         42
# Chesapeake_Bay_retriever           41
# French_bulldog                     41
# toy_poodle                         37
# cocker_spaniel                     34
# miniature_poodle                   33
# Siberian_husky                     33
# beagle                             28
# Eskimo_dog                         27
# collie                             27
# Pembroke                           27
# kuvasz                             26
# Italian_greyhound                  22
# Pekinese                           21
# American_Staffordshire_terrier     21
# miniature_pinscher                 20
# malinois                           20
# Samoyed                            20
# chow                               20
# toy_terrier                        20
# Boston_bull                        19
# ...

# %%
#Check p3 breed
df_twitter_img_pred[df_twitter_img_pred['p3_dog'] == True]['p3'].value_counts()
# Out:
# Labrador_retriever                79
# Chihuahua                         58
# golden_retriever                  48
# Eskimo_dog                        38
# kelpie                            35
# kuvasz                            34
# Staffordshire_bullterrier         32
# chow                              32
# cocker_spaniel                    31
# beagle                            31
# toy_poodle                        29
# Pekinese                          29
# Pomeranian                        29
# Pembroke                          27
# Great_Pyrenees                    27
# Chesapeake_Bay_retriever          27
# malamute                          26
# French_bulldog                    26
# American_Staffordshire_terrier    24
# Cardigan                          23
# pug                               23
# basenji                           21
# bull_mastiff                      20
# toy_terrier                       20
# Siberian_husky                    19
# ...

# %% [markdown]
# **Quality issues**
# - The predicted name is without pattern: some with underline, others with dash and also tiny
# - There are tweets where it was not possible to predict the breed of the dog in any of the images
# - In some cases p1_conf is not a dog but p2_conf or p3_conf can be dog

# %% [markdown]
# ### Additional data from Twitter

# %%
#Visualize the data
df_twitter_additional
# Out:
#                       id  favorite_count  retweet_count lang
# 0     892420643555336193           39467           8853   en
# 1     892177421306343426           33819           6514   en
# 2     891815181378084864           25461           4328   en
# 3     891689557279858688           42908           8964   en
# 4     891327558926688256           41048           9774   en
# 5     891087950875897856           20562           3261   en
# 6     890971913173991426           12041           2158   en
# 7     890729181411237888           56848          16716   en
# 8     890609185150312448           28226           4429   en
# 9     890240255349198849           32467           7711   en
# 10    890006608113172480           31166           7624   en
# 11    889880896479866881           28268           5156   en
# 12    889665388333682689           38818           8538   en
# 13    889638837579907072           27672           4735   en
# ...

# %%
#Check info
df_twitter_additional.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 4 columns):
# id                2354 non-null int64
# favorite_count    2354 non-null int64
# retweet_count     2354 non-null int64
# lang              2354 non-null object
# dtypes: int64(3), object(1)
# memory usage: 64.4+ KB

# %%
#Check describe
df_twitter_additional.describe()
# Out:
#                              id  favorite_count  retweet_count
# count               2354.000000     2354.000000    2354.000000
# mean  742697816435063552.000000     8080.968564    3164.797366
# std    68528120712910648.000000    11814.771334    5284.770364
# min   666020888022790144.000000        0.000000       0.000000
# 25%   678397510244808704.000000     1415.000000     624.500000
# 50%   719459571111233536.000000     3603.500000    1473.500000
# 75%   799305849241918464.000000    10122.250000    3652.000000
# max   892420643555336192.000000   132810.000000   79515.000000

# %% [markdown]
# **Quality issues**
# - The id column is not in the same name pattern as the other dataframes

# %%
df_twitter_additional.lang.value_counts()
# Out:
# en     2336
# und       7
# in        3
# nl        3
# eu        1
# tl        1
# et        1
# es        1
# ro        1
# Name: lang, dtype: int64

# %% [markdown]
# ### General tidiness issues

# %% [markdown]
# The data is segmented into 3 separate files although there is the same observational unit

# %% [markdown]
# ## Cleaning data

# %% [markdown]
# ### WeRateDogs Twitter archive

# %%
#Creating df copy
df_twitter_enhanced_clean = df_twitter_enhanced.copy()

# %% [markdown]
# #### Quality issues

# %% [markdown]
# **Columns names that do not express the data well**
#
# **Define**
#
# Change columns names

# %% [markdown]
# **Code**

# %%
#Retrieve column list
df_twitter_enhanced_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
df_twitter_enhanced_clean = df_twitter_enhanced_clean.rename(columns={'timestamp':'tweet_timestamp',
                                          'source':'tweet_source',
                                          'text':'tweet_text',
                                          'expanded_urls':'tweet_expanded_urls',
                                          'rating_numerator':'dog_rating_numerator',
                                          'rating_denominator':'dog_rating_denominator',
                                          'name':'dog_name'
                                         })

# %% [markdown]
# **Test**

# %%
df_twitter_enhanced_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id',
#        'tweet_timestamp', 'tweet_source', 'tweet_text', 'retweeted_status_id',
#        'retweeted_status_user_id', 'retweeted_status_timestamp',
#        'tweet_expanded_urls', 'dog_rating_numerator', 'dog_rating_denominator',
#        'dog_name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %% [markdown]
# **No columns for dog stages snoot and blep and the dog stages columns is not accurate**
#
# **Define**
#
# Add columns and use pandas contains in text field to re-extract dog stage

# %% [markdown]
# **Code**

# %%
#Creating column for snoot and blep
df_twitter_enhanced_clean['snoot'] = 'None'
df_twitter_enhanced_clean['blep'] = 'None'
df_twitter_enhanced_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    nan                  nan
# 1  892177421306343426                    nan                  nan
# 2  891815181378084864                    nan                  nan
# 3  891689557279858688                    nan                  nan
# 4  891327558926688256                    nan                  nan
#
#              tweet_timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                         tweet_source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
list_stages = ['doggo','floofer','pupper','puppo','snoot','blep']
for item in list_stages:
    df_twitter_enhanced_clean.loc[df_twitter_enhanced_clean['tweet_text'].str.lower().str.contains(item), [item]] = item

# %% [markdown]
# **Test**

# %%
#Originial df
df_twitter_enhanced.groupby(['doggo','floofer','pupper','puppo']).count()['tweet_id'].reset_index()
# Out:
#    doggo  floofer  pupper  puppo  tweet_id
# 0   None     None    None   None      1976
# 1   None     None    None  puppo        29
# 2   None     None  pupper   None       245
# 3   None  floofer    None   None         9
# 4  doggo     None    None   None        83
# 5  doggo     None    None  puppo         1
# 6  doggo     None  pupper   None        12
# 7  doggo  floofer    None   None         1

# %%
#Clean df
df_twitter_enhanced_clean.groupby(['doggo','floofer','pupper','puppo','snoot','blep']).count()['tweet_id'].reset_index()
# Out:
#    doggo  floofer  pupper  puppo snoot  blep  tweet_id
# 0   None     None    None   None  None  None      1930
# 1   None     None    None   None  None  blep         3
# 2   None     None    None  puppo  None  None        36
# 3   None     None  pupper   None  None  None       270
# 4   None     None  pupper   None  None  blep         1
# 5   None  floofer    None   None  None  None         9
# 6  doggo     None    None   None  None  None        92
# 7  doggo     None    None  puppo  None  None         2
# 8  doggo     None  pupper   None  None  None        12
# 9  doggo  floofer    None   None  None  None         1

# %% [markdown]
# **Rating denominator less or greather then 10**
#
# **Define**
#
# Update denominator  to 10 using pandas loc

# %% [markdown]
# **Code**

# %%
#Update value
df_twitter_enhanced_clean.loc[(df_twitter_enhanced_clean['dog_rating_denominator'] < 10) | (df_twitter_enhanced_clean['dog_rating_denominator'] > 10),['dog_rating_denominator']] = 10

# %% [markdown]
# **Test**

# %%
df_twitter_enhanced_clean.dog_rating_denominator.value_counts()
# Out:
# 10    2356
# Name: dog_rating_denominator, dtype: int64

# %% [markdown]
# **The source column is with html tag text**
#
# **Define**
#
# Split text to remove html tag

# %% [markdown]
# **Code**

# %%
#Checking column
with pd.option_context('display.max_colwidth', -1):
  display(df_twitter_enhanced_clean[['tweet_source']].head())
# Out:
#                                                                          tweet_source
# 0  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 3  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 4  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>

# %%
#Update source without tag
df_twitter_enhanced_clean['tweet_source'] = df_twitter_enhanced_clean['tweet_source'].str.split('>').str[1].str[:-3]

# %% [markdown]
# **Test**

# %%
#Count by source
df_twitter_enhanced_clean.tweet_source.value_counts()
# Out:
# Twitter for iPhone     2221
# Vine - Make a Scene      91
# Twitter Web Client       33
# TweetDeck                11
# Name: tweet_source, dtype: int64

# %% [markdown]
# The results look good to me, but i will check on original df

# %%
#Checking original df to view some cases
with pd.option_context('display.max_colwidth', -1):
    display(df_twitter_enhanced[df_twitter_enhanced['source'].str.contains('Vine - Make a Scene')].head())
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 529  808344865868283904 nan                    nan
# 562  802600418706604034 nan                    nan
# 657  791774931465953280 nan                    nan
# 672  789903600034189313 nan                    nan
# 699  786286427768250368 nan                    nan
#
#                      timestamp  \
# 529  2016-12-12 16:16:49 +0000
# 562  2016-11-26 19:50:26 +0000
# 657  2016-10-27 22:53:48 +0000
# 672  2016-10-22 18:57:48 +0000
# 699  2016-10-12 19:24:27 +0000
#
#                                                               source  \
# 529  <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
# 562  <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
# 657  <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
# 672  <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
# 699  <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>
#
# ...

# %%
#Checking original df to view some cases
with pd.option_context('display.max_colwidth', -1):
    display(df_twitter_enhanced[df_twitter_enhanced['source'].str.contains('TweetDeck')].head())
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 972  750086836815486976 nan                    nan
# 974  750056684286914561 nan                    nan
# 975  750041628174217216 nan                    nan
# 976  750026558547456000 nan                    nan
# 977  750011400160841729 nan                    nan
#
#                      timestamp  \
# 972  2016-07-04 22:00:12 +0000
# 974  2016-07-04 20:00:23 +0000
# 975  2016-07-04 19:00:33 +0000
# 976  2016-07-04 18:00:41 +0000
# 977  2016-07-04 17:00:26 +0000
#
#                                                                                   source  \
# 972  <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# 974  <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# 975  <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>
# ...

# %% [markdown]
# **The timestamp column as an object instead of a date**
#
# **Define**
#
# Change column datatype

# %% [markdown]
# **Code**

# %%
#Change columns datatype
df_twitter_enhanced_clean = df_twitter_enhanced_clean.astype({'tweet_timestamp': 'datetime64'})

# %% [markdown]
# **Test**

# %%
#Check data types
df_twitter_enhanced_clean.dtypes
# Out:
# tweet_id                               int64
# in_reply_to_status_id                float64
# in_reply_to_user_id                  float64
# tweet_timestamp               datetime64[ns]
# tweet_source                          object
# tweet_text                            object
# retweeted_status_id                  float64
# retweeted_status_user_id             float64
# retweeted_status_timestamp            object
# tweet_expanded_urls                   object
# dog_rating_numerator                   int64
# dog_rating_denominator                 int64
# dog_name                              object
# doggo                                 object
# floofer                               object
# pupper                                object
# puppo                                 object
# snoot                                 object
# blep                                  object
# dtype: object

# %%
#Check data
df_twitter_enhanced_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    nan                  nan
# 1  892177421306343426                    nan                  nan
# 2  891815181378084864                    nan                  nan
# 3  891689557279858688                    nan                  nan
# 4  891327558926688256                    nan                  nan
#
#       tweet_timestamp        tweet_source  \
# 0 2017-08-01 16:23:56  Twitter for iPhone
# 1 2017-08-01 00:17:27  Twitter for iPhone
# 2 2017-07-31 00:18:03  Twitter for iPhone
# 3 2017-07-30 15:58:51  Twitter for iPhone
# 4 2017-07-29 16:00:24  Twitter for iPhone
#
#                                           tweet_text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  nan
# 1  This is Tilly. She's just checking pup on you....                  nan
# 2  This is Archie. He is a rare Norwegian Pouncin...                  nan
# ...

# %% [markdown]
# **We have retweets and in replies**
#
# **Define**
#
# Remove the data

# %% [markdown]
# **Code**

# %%
#Filtering retweeted_status_id and in_reply_to_status_id
df_twitter_enhanced_clean = df_twitter_enhanced_clean[df_twitter_enhanced_clean['retweeted_status_id'].isnull()]
df_twitter_enhanced_clean = df_twitter_enhanced_clean[df_twitter_enhanced_clean['in_reply_to_status_id'].isnull()]

# %% [markdown]
# **Test**

# %%
df_twitter_enhanced_clean.retweeted_status_id.count()
# Out:
# 0

# %%
df_twitter_enhanced_clean.in_reply_to_status_id.count()
# Out:
# 0

# %% [markdown]
# #### Tidiness issues

# %% [markdown]
# **All dog stage columns can become a single category column**
#
# **Define**
#
# Replace "None" to Nan and concatenate all dog stage columns in a final column "dog_stages" and them drop the old columns

# %% [markdown]
# **Code**

# %%
#Replace None to NaN
df_twitter_enhanced_clean.replace('None',np.NaN,inplace=True)

# %%
#Concatenate columns
df_twitter_enhanced_clean['dog_stage'] = df_twitter_enhanced_clean[['doggo','floofer','pupper','puppo','snoot','blep']].apply(lambda x: ','.join(x[x.notna()]), axis=1)

# %% [markdown]
# **Test**

# %%
df_twitter_enhanced_clean.dog_stage.value_counts()
# Out:
#                  1720
# pupper            245
# doggo              79
# puppo              28
# floofer             9
# doggo,pupper        9
# blep                3
# doggo,puppo         2
# pupper,blep         1
# doggo,floofer       1
# Name: dog_stage, dtype: int64

# %%
#Remove old columns
df_twitter_enhanced_clean.drop(['doggo','floofer','pupper','puppo','snoot','blep'], axis='columns', inplace=True)

# %%
df_twitter_enhanced_clean.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    nan                  nan
# 1  892177421306343426                    nan                  nan
# 2  891815181378084864                    nan                  nan
# 3  891689557279858688                    nan                  nan
# 4  891327558926688256                    nan                  nan
#
#       tweet_timestamp        tweet_source  \
# 0 2017-08-01 16:23:56  Twitter for iPhone
# 1 2017-08-01 00:17:27  Twitter for iPhone
# 2 2017-07-31 00:18:03  Twitter for iPhone
# 3 2017-07-30 15:58:51  Twitter for iPhone
# 4 2017-07-29 16:00:24  Twitter for iPhone
#
#                                           tweet_text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  nan
# 1  This is Tilly. She's just checking pup on you....                  nan
# 2  This is Archie. He is a rare Norwegian Pouncin...                  nan
# ...

# %% [markdown]
# ### Tweet additional data

# %%
#Create a copy df
df_twitter_additional_clean = df_twitter_additional.copy()

# %% [markdown]
# **Quality issues**
#
# The id column is not in the same name pattern as the other dataframes
#
# **Define**
#
# Rename id column to tweet_id

# %% [markdown]
# **Code**

# %%
#Rename column
df_twitter_additional_clean = df_twitter_additional_clean.rename(columns={'id':'tweet_id'})

# %% [markdown]
# **Test**

# %%
df_twitter_additional_clean.head()
# Out:
#              tweet_id  favorite_count  retweet_count lang
# 0  892420643555336193           39467           8853   en
# 1  892177421306343426           33819           6514   en
# 2  891815181378084864           25461           4328   en
# 3  891689557279858688           42908           8964   en
# 4  891327558926688256           41048           9774   en

# %% [markdown]
# ### Tweet image predictions

# %%
#Create a copy df
df_twitter_img_pred_clean = df_twitter_img_pred.copy()

# %% [markdown]
# **Quality issues**

# %% [markdown]
# **The predicted names is without pattern: some with underline, others with dash and also tiny**
#
# **Define**
#
# Replace underline and dash for space and title text

# %% [markdown]
# **Code**

# %%
#Replace underline and dash and title text
df_twitter_img_pred_clean['p1'] = df_twitter_img_pred_clean['p1'].str.replace('_|-',' ').str.title()
df_twitter_img_pred_clean['p2'] = df_twitter_img_pred_clean['p2'].str.replace('_|-',' ').str.title()
df_twitter_img_pred_clean['p3'] = df_twitter_img_pred_clean['p3'].str.replace('_|-',' ').str.title()

# %% [markdown]
# **Test**

# %%
df_twitter_img_pred_clean.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1  p1_conf  p1_dog                  p2  \
# 0        1  Welsh Springer Spaniel 0.465074    True              Collie
# 1        1                 Redbone 0.506826    True  Miniature Pinscher
# 2        1         German Shepherd 0.596461    True            Malinois
# 3        1     Rhodesian Ridgeback 0.408143    True             Redbone
# 4        1      Miniature Pinscher 0.560311    True          Rottweiler
#
#    p2_conf  p2_dog                   p3  p3_conf  p3_dog
# ...

# %% [markdown]
# **There are tweets where it was not possible to predict the breed of the dog in any of the images**
#
# **Define**
#
# Remove the cases

# %% [markdown]
# **Code**

# %%
#Remove non dogs images
df_twitter_img_pred_clean = df_twitter_img_pred_clean.loc[(df_twitter_img_pred_clean['p1_dog'] == True) | (df_twitter_img_pred_clean['p2_dog'] == True) | (df_twitter_img_pred_clean['p3_dog'] == True)]

# %% [markdown]
# **Test**

# %%
#Check p's
df_twitter_img_pred_clean.groupby(['p1_dog','p2_dog','p3_dog']).count()['tweet_id'].reset_index()
# Out:
#    p1_dog  p2_dog  p3_dog  tweet_id
# 0   False   False    True        64
# 1   False    True   False        54
# 2   False    True    True       101
# 3    True   False   False        43
# 4    True   False    True        91
# 5    True    True   False       155
# 6    True    True    True      1243

# %% [markdown]
# **In some cases p1_dog is not a dog but p2_dog or p3_dog can be dog**
#
# **Define**
#
# Select the breed column with TRUE on px_dog

# %% [markdown]
# **Code**

# %%
df_twitter_img_pred_clean['dog_breed'] = np.where((df_twitter_img_pred_clean['p1_dog'] == True) , df_twitter_img_pred_clean['p1'], 
np.where((df_twitter_img_pred_clean['p1_dog'] == False) & (df_twitter_img_pred_clean['p2_dog'] == True) , df_twitter_img_pred_clean['p2'],
         df_twitter_img_pred_clean['p3']
        ))

# %% [markdown]
# **Test**

# %%
#Grouping to check dog breed column
df_twitter_img_pred_clean.groupby(['p1','p1_dog','p2','p2_dog','p3','p3_dog','dog_breed']).count()['tweet_id'].reset_index()
# Out:
#                                   p1  p1_dog                              p2  \
# 0                       Acorn Squash   False                        Shih Tzu
# 1                       Acorn Squash   False                     Toilet Seat
# 2                       Afghan Hound    True                          Basset
# 3                       Afghan Hound    True                          Borzoi
# 4                       Afghan Hound    True                          Saluki
# 5                African Hunting Dog   False                            Plow
# 6                           Airedale    True                  Border Terrier
# 7                           Airedale    True                      Brown Bear
# 8                           Airedale    True                  Cocker Spaniel
# 9                           Airedale    True                   Irish Terrier
# 10                          Airedale    True                   Irish Terrier
# ...

# %% [markdown]
# ### General tideness issue
#
# **The data is segmented into 3 separate files although there is the same observational unit**
#
# **Define**
#
# Merge data in a master dataframe

# %% [markdown]
# **Code**

# %%
#Check columns
df_twitter_enhanced_clean.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id',
#        'tweet_timestamp', 'tweet_source', 'tweet_text', 'retweeted_status_id',
#        'retweeted_status_user_id', 'retweeted_status_timestamp',
#        'tweet_expanded_urls', 'dog_rating_numerator', 'dog_rating_denominator',
#        'dog_name', 'dog_stage'],
#       dtype='object')

# %%
#Check columns
df_twitter_additional_clean.columns
# Out:
# Index(['tweet_id', 'favorite_count', 'retweet_count', 'lang'], dtype='object')

# %%
#Check columns
df_twitter_img_pred_clean.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog', 'dog_breed'],
#       dtype='object')

# %%
#Merge dataframes
enhanced_list = ['tweet_id','tweet_timestamp','tweet_source','tweet_text','dog_name','dog_stage','dog_rating_numerator', 'dog_rating_denominator']
pred_list = ['tweet_id', 'dog_breed']

twitter_archive_master = pd.merge(pd.merge(df_twitter_enhanced_clean[enhanced_list],
                  df_twitter_additional_clean,on='tweet_id'),
                  df_twitter_img_pred_clean[pred_list],on='tweet_id', how='left')

# %% [markdown]
# **Test**

# %%
#Check master df
twitter_archive_master.head()
# Out:
#              tweet_id     tweet_timestamp        tweet_source  \
# 0  892420643555336193 2017-08-01 16:23:56  Twitter for iPhone
# 1  892177421306343426 2017-08-01 00:17:27  Twitter for iPhone
# 2  891815181378084864 2017-07-31 00:18:03  Twitter for iPhone
# 3  891689557279858688 2017-07-30 15:58:51  Twitter for iPhone
# 4  891327558926688256 2017-07-29 16:00:24  Twitter for iPhone
#
#                                           tweet_text  dog_name dog_stage  \
# 0  This is Phineas. He's a mystical boy. Only eve...   Phineas
# 1  This is Tilly. She's just checking pup on you....     Tilly
# 2  This is Archie. He is a rare Norwegian Pouncin...    Archie
# 3  This is Darla. She commenced a snooze mid meal...     Darla
# 4  This is Franklin. He would like you to stop ca...  Franklin
#
#    dog_rating_numerator  dog_rating_denominator  favorite_count  \
# 0                    13                      10           39467
# 1                    13                      10           33819
# ...

# %% [markdown]
# ## Storing master dataframe

# %%
#Storage in csv file
twitter_archive_master.to_csv('C:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/data/twitter_archive_master.csv')

# %% [markdown]
# ## Analysing data
#
# What questions would we like to answer?
#
# - What is the most common dogs breed in WeRateDogs posts?
# - What are the breeds with the highest favorite count mean ?
# - What are the breeds with the highest retweet count mean ?
# - What is the most common dogs stage (When does this information exist)?
# - How are evaluations distribution ?

# %% [markdown]
# **What is the most common breed of dog in WeRateDogs posts?**

# %%
#Calculate top 10 dog breed
df_count = twitter_archive_master.dog_breed.value_counts().reset_index().head(10).rename(columns = {'index': 'dog_breed', 'dog_breed': 'count'})

#Adjust fig size
fig, ax = plt.subplots(figsize=[20,7])

#Barplot
sns.barplot(x='dog_breed',y='count',data=df_count)
plt.title('Most common dogs breed in WeRateDogs posts')
plt.savefig('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/notebooks/most_commom_dog_breed.png')
plt.show()

# %% [markdown]
# **What are the breeds with the highest favorite count mean ?**

# %%
#Calculate top 10 dog breed
df_count = twitter_archive_master.groupby('dog_breed').mean()['favorite_count'].sort_values(ascending=False).reset_index().head(10)

#Adjust fig size
fig, ax = plt.subplots(figsize=[20,7])

#Barplot
sns.barplot(x='dog_breed',y='favorite_count',data=df_count)
plt.title('Dogs breed with most favorite count mean')
plt.savefig('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/notebooks/dog_breed_favorite.png')
plt.show()

# %% [markdown]
# **What are the breeds with the highest retweet count mean ?**

# %%
#Calculate top 10 dog breed
df_count = twitter_archive_master.groupby('dog_breed').mean()['retweet_count'].sort_values(ascending=False).reset_index().head(10)

#Adjust fig size
fig, ax = plt.subplots(figsize=[20,7])

#Barplot
sns.barplot(x='dog_breed',y='retweet_count',data=df_count)
plt.title('Dogs breed with most retweet count mean')
plt.savefig('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/notebooks/dog_breed_retweet.png')
plt.show()

# %% [markdown]
# **What is the most common dogs stage (When does this information exist)?**

# %%
#Calculate top 10 dog breed
df_count = twitter_archive_master.dog_stage.value_counts().reset_index().rename(columns = {'index': 'dog_stage', 'dog_stage': 'count'})
df_count = df_count[df_count['dog_stage'] != '']

#Adjust fig size
fig, ax = plt.subplots(figsize=[20,7])

#Barplot
sns.barplot(x='dog_stage',y='count',data=df_count)
plt.title('Most common dog stage in WeRateDogs posts')
plt.savefig('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/notebooks/most_commom_dog_stage.png')
plt.show()

# %% [markdown]
# **How are evaluations distribution ?**

# %%
twitter_archive_master.dog_rating_numerator.describe()
# Out:
# count   2097.000000
# mean      12.189318
# std       40.364996
# min        0.000000
# 25%       10.000000
# 50%       11.000000
# 75%       12.000000
# max     1776.000000
# Name: dog_rating_numerator, dtype: float64

# %%
#Calculate top 10 dog breed
df_count = twitter_archive_master.dog_rating_numerator.value_counts().reset_index().rename(columns = {'index': 'dog_rating_numerator', 'dog_rating_numerator': 'count'})
df_count = df_count[df_count['dog_rating_numerator'] <= 15] #limit in 15

#Adjust fig size
fig, ax = plt.subplots(figsize=[20,7])

#Barplot
sns.barplot(x='dog_rating_numerator',y='count',data=df_count)
plt.title('Evaluations distribuition')
plt.savefig('c:/git-repository/data-analyst-nanodegree/projects/project-4-wrangling-and-analyze-data/notebooks/evaluations_distribuition.png')
plt.show()

# %% [markdown]
# ## Insights
#
# - Golden, Labrador and Pembroke are the most commom dog breed in WeRateDogs posts
# - Although the breeds mentioned in the previous item have more posts, when we evaluate the popularity measures (favorite and retweets), we can identify that other breeds stand out, like:
#     - Bedlington Terrier can be considered the most popular breed, as it appears as the second breed with most favorites and the breed with the highest number of retweets
#     - Saluki
#     - Afghan Hound
#     - French Bulldog
# - From what it was possible to identify in the text, we see that most of the posts are related to puppos dog
# - Most dogs receive grades between 10 and 13
# - The dogs with the highest number of posts are also the most favorite and retweeted
